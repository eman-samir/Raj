# %%
import os
import re
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS

# %% [markdown]
# # clean text

# %%
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^a-zA-Z0-9.,!?()\- ]', '', text)
    text = re.sub(r'[.,!?]{2,}', '.', text)
    return text.strip()

# %% [markdown]
# # load text

# %%
def load_documents(folder_path):
    docs = []
    for file in os.listdir(folder_path):
        if file.endswith(".txt"):
            path = os.path.join(folder_path, file)
            loader = TextLoader(path, encoding="utf-8")
            loaded_docs = loader.load()

            for doc in loaded_docs:
                doc.page_content = clean_text(doc.page_content)

            docs.extend(loaded_docs)

    return docs

# %% [markdown]
# # split document

# %%
def split_documents(documents):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=50
    )
    return splitter.split_documents(documents)

# %% [markdown]
# # creat vector

# %%
def create_vectorstore(documents):
    embeddings = HuggingFaceBgeEmbeddings(
        model_name="BAAI/bge-base-en-v1.5",
        encode_kwargs={'normalize_embeddings': True}
    )

    db = FAISS.from_documents(documents, embeddings)
    db.save_local("vectorstore")

    return db

# %% [markdown]
# # to run everything

# %%
print("Starting ingestion...")

docs = load_documents("data")
print(f"Loaded {len(docs)} documents")

split_docs = split_documents(docs)
print(f"Split into {len(split_docs)} chunks")


#db = create_vectorstore(split_docs)

print("✅ Vectorstore created successfully!")
# Out:
# Starting ingestion...
# Loaded 12 documents
# Split into 16739 chunks
# ✅ Vectorstore created successfully!

# %% [markdown]
# # load vector

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = HuggingFaceBgeEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    encode_kwargs={'normalize_embeddings': True}
)

db = FAISS.load_local(
    "vectorstore",
    embeddings,
    allow_dangerous_deserialization=True
)

print("✅ Vectorstore loaded!")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22848\4130410182.py:4: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceBgeEmbeddings(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Vectorstore loaded!

# %% [markdown]
# # gemini API

# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (2.30.3)
# Requirement already satisfied: google-api-python-client in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (2.194.0)
# Requirement already satisfied: google-auth>=2.15.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (2.49.2)
# Requirement already satisfied: protobuf in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (2.12.5)
# Requirement already satisfied: tqdm in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (4.67.3)
# Requirement already satisfied: typing-extensions in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-core->google-generativeai) (1.74.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2026.2.25)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-python-client->google-generativeai) (0.3.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\Lenovo\miniconda3\envs\my_py\Lib\site-packages (from tqdm->google-generativeai) (0.4.6)

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyBCNwwQORlm1Nm6IABBjS3jMbWO3v7MMGw")

model = genai.GenerativeModel("gemini-1.5-pro")

print("✅ Gemini ready!")
# Out:
# ✅ Gemini ready!
